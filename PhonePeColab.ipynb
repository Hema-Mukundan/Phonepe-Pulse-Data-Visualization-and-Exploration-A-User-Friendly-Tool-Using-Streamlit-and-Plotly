# %% [markdown]
# <a href="https://colab.research.google.com/github/Hema-Mukundan/Hema-Mukundan/blob/main/PhonePeColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create GitHub repo clone
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# Cloning into 'pulse'...
# remote: Enumerating objects: 8891, done.
# remote: Counting objects: 100% (8891/8891), done.
# remote: Compressing objects: 100% (7400/7400), done.
# remote: Total 8891 (delta 2789), reused 7257 (delta 1170), pack-reused 0
# Receiving objects: 100% (8891/8891), 2.30 MiB | 4.84 MiB/s, done.
# Resolving deltas: 100% (2789/2789), done.

# %%
#Loading required libraries
import pandas as pd
import json
import os

# %%
#This is to direct the path to get the data as states

path="/content/pulse/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India
# Out:
# ['sikkim',
#  'mizoram',
#  'meghalaya',
#  'punjab',
#  'nagaland',
#  'tamil-nadu',
#  'jammu-&-kashmir',
#  'assam',
#  'west-bengal',
#  'gujarat',
#  'odisha',
#  'andhra-pradesh',
#  'kerala',
#  'madhya-pradesh',
#  'rajasthan',
#  'ladakh',
#  'uttar-pradesh',
#  'manipur',
#  'himachal-pradesh',
#  'bihar',
#  'lakshadweep',
#  'maharashtra',
#  'arunachal-pradesh',
#  'chandigarh',
#  'puducherry',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'goa',
#  'jharkhand',
#  'haryana',
#  'delhi',
#  'uttarakhand',
#  'andaman-&-nicobar-islands',
#  'chhattisgarh',
#  'tripura',
#  'karnataka',
#  'telangana']

# %%
#extract the aggregated_transaction data and transform it to a dataframe
clm={'State':[], 'Year':[],'Quarter':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)

    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)

        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)

            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transaction_type'].append(Name)
              clm['Transaction_count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quarter'].append(int(k.strip('.json')))

Agg_Trans=pd.DataFrame(clm)

# %%
Agg_Trans
# Out:
#           State  Year  Quarter          Transaction_type  Transaction_count  \
# 0        sikkim  2022        4     Peer-to-peer payments            1548662
# 1        sikkim  2022        4         Merchant payments            1033541
# 2        sikkim  2022        4  Recharge & bill payments             470639
# 3        sikkim  2022        4        Financial Services               2049
# 4        sikkim  2022        4                    Others               3448
# ...         ...   ...      ...                       ...                ...
# 3949  telangana  2020        1     Peer-to-peer payments           95668911
# 3950  telangana  2020        1         Merchant payments           76818285
# 3951  telangana  2020        1  Recharge & bill payments           26324268
# 3952  telangana  2020        1        Financial Services              88184
# 3953  telangana  2020        1                    Others             509877
#
#       Transaction_amount
# 0           5.175155e+09
# 1           1.096221e+09
# 2           1.812817e+08
# 3           2.701972e+06
# 4           3.025622e+06
# ...                  ...
# 3949        3.276418e+11
# 3950        3.107643e+10
# 3951        1.232427e+10
# 3952        5.950064e+07
# 3953        2.417841e+08
#
# [3954 rows x 6 columns]

# %%
# extract aggregated_users data and transform it into dataframe
path="/content/pulse/data/aggregated/user/country/india/state/"
agg_state_list = os.listdir(path)

clm = {'State': [], 'Year': [], 'Quarter': [], 'User_brand': [], 'User_count': [], 'User_percentage': []}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)

    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)

        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            try:
              for z in D['data']['usersByDevice']:
                brand = z['brand']
                count = z['count']
                percentage = z['percentage']*100
                clm['User_brand'].append(brand)
                clm['User_count'].append(count)
                clm['User_percentage'].append(percentage)
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quarter'].append(int(k.strip('.json')))
            except:
              pass
clm
Agg_user = pd.DataFrame(clm)

# %%
Agg_user
# Out:
#                   State  Year  Quarter User_brand  User_count  User_percentage
# 0     arunachal-pradesh  2021        1       Vivo       58748        23.383219
# 1     arunachal-pradesh  2021        1     Xiaomi       57405        22.848671
# 2     arunachal-pradesh  2021        1    Samsung       48405        19.266438
# 3     arunachal-pradesh  2021        1       Oppo       39602        15.762617
# 4     arunachal-pradesh  2021        1     Realme       18658         7.426365
# ...                 ...   ...      ...        ...         ...              ...
# 6727          rajasthan  2019        2     Huawei      163775         1.864483
# 6728          rajasthan  2019        2    OnePlus      142119         1.617942
# 6729          rajasthan  2019        2     Gionee      135881         1.546926
# 6730          rajasthan  2019        2   Motorola      131957         1.502254
# 6731          rajasthan  2019        2     Others      902419        10.273516
#
# [6732 rows x 6 columns]

# %%
#extract Map_transaction data and transform into dataframe
path="/content/pulse/data/map/transaction/hover/country/india/state/"
agg_state_list = os.listdir(path)

clm = {'State': [], 'Year': [], 'Quarter': [], 'District': [], 'Transaction_count': [], 'Transaction_amount': []}

for i in agg_state_list:
    path_i = path + i + '/'
    agg_year_list = os.listdir(path_i)

    for j in agg_year_list:
        path_j = path_i + j + '/'
        agg_year_json = os.listdir(path_j)

        for k in agg_year_json:
            path_k = path_j + k
            Data = open(path_k, 'r')
            d = json.load(Data)
            try:
              for z in d['data']['hoverDataList']:
                  district = z['name'].split('district')[0]
                  count = z['metric'][0]['count']
                  amount = z['metric'][0]['amount']
                  clm['District'].append(district)
                  clm['Transaction_count'].append(count)
                  clm['Transaction_amount'].append(amount)
                  clm['State'].append(i)
                  clm['Year'].append(j)
                  clm['Quarter'].append(int(k.strip('.json')))
            except:
              pass

map_transaction = pd.DataFrame(clm)

# %%
map_transaction
# Out:
#                    State  Year  Quarter              District  \
# 0      arunachal-pradesh  2021        1  lower dibang valley
# 1      arunachal-pradesh  2021        1      lower subansiri
# 2      arunachal-pradesh  2021        1             longding
# 3      arunachal-pradesh  2021        1           west siang
# 4      arunachal-pradesh  2021        1                kamle
# ...                  ...   ...      ...                   ...
# 16095          rajasthan  2019        2                bundi
# 16096          rajasthan  2019        2             jhalawar
# 16097          rajasthan  2019        2                alwar
# 16098          rajasthan  2019        2                 kota
# 16099          rajasthan  2019        2            jhunjhunu
#
#        Transaction_count  Transaction_amount
# 0                  32427        9.070911e+07
# 1                  29916        1.065912e+08
# 2                  23962        7.557342e+07
# 3                  42575        1.387006e+08
# 4                   3092        1.102377e+07
# ...                  ...                 ...
# 16095             335788        4.528193e+08
# 16096             423714        7.830305e+08
# 16097            2451727        4.430720e+09
# 16098            1571917        2.185106e+09
# 16099            1128965        2.364089e+09
#
# [16100 rows x 6 columns]

# %%
#extract Map_users data and transform into dataframe
path="/content/pulse/data/map/user/hover/country/india/state/"
agg_state_list = os.listdir(path)

clm = {'State': [], 'Year': [], 'Quarter': [], 'District': [], 'Registered_user': [], 'App_opens': []}
for i in agg_state_list:
    path_i = path + i + '/'
    agg_year_list = os.listdir(path_i)

    for j in agg_year_list:
        path_j = path_i + j + '/'
        agg_year_json = os.listdir(path_j)

        for k in agg_year_json:
            path_k = path_j + k
            Data = open(path_k, 'r')
            d = json.load(Data)

            for z_key, z_value in d['data']['hoverData'].items():
                district = z_key.split('district')[0]
                reg_user = z_value['registeredUsers']
                app_opens = z_value['appOpens']
                clm['District'].append(district)
                clm['Registered_user'].append(reg_user)
                clm['App_opens'].append(app_opens)
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quarter'].append(int(k.strip('.json')))

map_user = pd.DataFrame(clm)

# %%
map_user
# Out:
#                    State  Year  Quarter          District  Registered_user  \
# 0      arunachal-pradesh  2021        1  lower subansiri              8044
# 1      arunachal-pradesh  2021        1            tirap              7376
# 2      arunachal-pradesh  2021        1       papum pare             84715
# 3      arunachal-pradesh  2021        1            anjaw              2660
# 4      arunachal-pradesh  2021        1      lower siang              3594
# ...                  ...   ...      ...               ...              ...
# 16099          rajasthan  2019        2            bundi             99226
# 16100          rajasthan  2019        2         jhalawar            106772
# 16101          rajasthan  2019        2            alwar            593855
# 16102          rajasthan  2019        2             kota            359152
# 16103          rajasthan  2019        2        jhunjhunu            275603
#
#        App_opens
# 0         136547
# 1         136247
# 2        1553363
# 3          55283
# 4          61226
# ...          ...
# 16099     630309
# 16100     774709
# 16101    4412522
# 16102    2477064
# 16103    1522271
#
# [16104 rows x 6 columns]

# %%
#extract Top_transaction_district data and transform into dataframe
path="/content/pulse/data/top/transaction/country/india/state/"
agg_state_list = os.listdir(path)

clm = {'State': [], 'Year': [], 'Quarter': [], 'District': [], 'Transaction_count': [], 'Transaction_amount': []}
for i in agg_state_list:
    path_i = path + i + '/'
    agg_year_list = os.listdir(path_i)

    for j in agg_year_list:
        path_j = path_i + j + '/'
        agg_year_json = os.listdir(path_j)

        for k in agg_year_json:
            path_k = path_j + k
            Data = open(path_k, 'r')
            d = json.load(Data)

            for z in d['data']['districts']:
                district = z['entityName']
                count = z['metric']['count']
                amount = z['metric']['amount']
                clm['District'].append(district)
                clm['Transaction_count'].append(count)
                clm['Transaction_amount'].append(amount)
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quarter'].append(int(k.strip('.json')))
Top_transaction_district = pd.DataFrame(clm)

# %%
Top_transaction_district
# Out:
#                   State  Year  Quarter     District  Transaction_count  \
# 0     arunachal-pradesh  2021        1   papum pare             419891
# 1     arunachal-pradesh  2021        1  west kameng             120906
# 2     arunachal-pradesh  2021        1   east siang              82357
# 3     arunachal-pradesh  2021        1    changlang              78849
# 4     arunachal-pradesh  2021        1        lohit              72380
# ...                 ...   ...      ...          ...                ...
# 6507          rajasthan  2019        2        sikar            1198479
# 6508          rajasthan  2019        2    jhunjhunu            1128965
# 6509          rajasthan  2019        2        ajmer            1078977
# 6510          rajasthan  2019        2        dausa            1063146
# 6511          rajasthan  2019        2      udaipur            1007076
#
#       Transaction_amount
# 0           1.388723e+09
# 1           3.847353e+08
# 2           2.539884e+08
# 3           2.201678e+08
# 4           1.985348e+08
# ...                  ...
# 6507        2.624571e+09
# 6508        2.364089e+09
# 6509        2.153454e+09
# 6510        1.644610e+09
# 6511        1.724896e+09
#
# [6512 rows x 6 columns]

# %%
#extract Top_transaction_Pincode data and transform into dataframe
path="/content/pulse/data/top/transaction/country/india/state/"
agg_state_list = os.listdir(path)

clm = {'State': [], 'Year': [], 'Quarter': [], 'Pincode': [], 'Transaction_count': [], 'Transaction_amount': []}
for i in agg_state_list:
    path_i = path + i + '/'
    agg_year_list = os.listdir(path_i)

    for j in agg_year_list:
        path_j = path_i + j + '/'
        agg_year_json = os.listdir(path_j)

        for k in agg_year_json:
            path_k = path_j + k
            Data = open(path_k, 'r')
            d = json.load(Data)

            for z in d['data']['pincodes']:
                pincode = z['entityName']
                count = z['metric']['count']
                amount = z['metric']['amount']
                clm['Pincode'].append(pincode)
                clm['Transaction_count'].append(count)
                clm['Transaction_amount'].append(amount)
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quarter'].append(int(k.strip('.json')))

Top_transaction_Pincode = pd.DataFrame(clm)

# %%
Top_transaction_Pincode
# Out:
#                   State  Year  Quarter Pincode  Transaction_count  \
# 0     arunachal-pradesh  2021        1  791113             127025
# 1     arunachal-pradesh  2021        1  791110             119184
# 2     arunachal-pradesh  2021        1  791111              89356
# 3     arunachal-pradesh  2021        1  791102              68000
# 4     arunachal-pradesh  2021        1  792103              53040
# ...                 ...   ...      ...     ...                ...
# 7848          rajasthan  2019        2  302020             734567
# 7849          rajasthan  2019        2  302022             622825
# 7850          rajasthan  2019        2  311001             580827
# 7851          rajasthan  2019        2  302018             540137
# 7852          rajasthan  2019        2  302033             481947
#
#       Transaction_amount
# 0           3.949590e+08
# 1           4.045021e+08
# 2           3.070147e+08
# 3           2.114320e+08
# 4           1.411567e+08
# ...                  ...
# 7848        9.993646e+08
# 7849        6.929173e+08
# 7850        1.084981e+09
# 7851        6.510254e+08
# 7852        5.335579e+08
#
# [7853 rows x 6 columns]

# %%
#extract Top_User_district data and transform into dataframe
path="/content/pulse/data/top/user/country/india/state/"
agg_state_list = os.listdir(path)

clm = {'State': [], 'Year': [], 'Quarter': [], 'District': [], 'Registered_user': []}
for i in agg_state_list:
    path_i = path + i + '/'
    agg_year_list = os.listdir(path_i)

    for j in agg_year_list:
        path_j = path_i + j + '/'
        agg_year_json = os.listdir(path_j)

        for k in agg_year_json:
            path_k = path_j + k
            Data = open(path_k, 'r')
            d = json.load(Data)

            for z in d['data']['districts']:
                district = z['name']
                reg_user = z['registeredUsers']
                clm['District'].append(district)
                clm['Registered_user'].append(reg_user)
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quarter'].append(int(k.strip('.json')))
Top_User_district = pd.DataFrame(clm)

# %%
Top_User_district
# Out:
#                   State  Year Quarter     District  Registered_user
# 0     arunachal-pradesh  2021      Q1   papum pare            84715
# 1     arunachal-pradesh  2021      Q1  west kameng            21027
# 2     arunachal-pradesh  2021      Q1    changlang            19716
# 3     arunachal-pradesh  2021      Q1   east siang            19342
# 4     arunachal-pradesh  2021      Q1        lohit            14231
# ...                 ...   ...     ...          ...              ...
# 6507          rajasthan  2019      Q2        ajmer           335167
# 6508          rajasthan  2019      Q2     bhilwara           314517
# 6509          rajasthan  2019      Q2       nagaur           301083
# 6510          rajasthan  2019      Q2      udaipur           296062
# 6511          rajasthan  2019      Q2    jhunjhunu           275603
#
# [6512 rows x 5 columns]

# %%
#extract Top_User_Pincode data and transform into dataframe
path="/content/pulse/data/top/user/country/india/state/"
agg_state_list = os.listdir(path)

clm = {'State': [], 'Year': [], 'Quarter': [], 'Pincode': [], 'Registered_user': []}
for i in agg_state_list:
    path_i = path + i + '/'
    agg_year_list = os.listdir(path_i)

    for j in agg_year_list:
        path_j = path_i + j + '/'
        agg_year_json = os.listdir(path_j)

        for k in agg_year_json:
            path_k = path_j + k
            Data = open(path_k, 'r')
            d = json.load(Data)

            for z in d['data']['pincodes']:
                pincode = z['name']
                reg_user = z['registeredUsers']
                clm['Pincode'].append(pincode)
                clm['Registered_user'].append(reg_user)
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quarter'].append(int(k.strip('.json')))
Top_User_Pincode = pd.DataFrame(clm)

# %%
Top_User_Pincode
# Out:
#                   State  Year  Quarter Pincode  Registered_user
# 0     arunachal-pradesh  2021        1  791110            26578
# 1     arunachal-pradesh  2021        1  791111            23660
# 2     arunachal-pradesh  2021        1  791113            16942
# 3     arunachal-pradesh  2021        1  791102            16191
# 4     arunachal-pradesh  2021        1  791001            12442
# ...                 ...   ...      ...     ...              ...
# 7849          rajasthan  2019        2  302017           105403
# 7850          rajasthan  2019        2  302001           104285
# 7851          rajasthan  2019        2  301001           101785
# 7852          rajasthan  2019        2  335001            92230
# 7853          rajasthan  2019        2  313001            90885
#
# [7854 rows x 5 columns]

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /usr/local/lib/python3.10/dist-packages (8.1.0)
# Collecting protobuf<=4.21.12,>=4.21.1 (from mysql-connector-python)
#   Using cached protobuf-4.21.12-cp37-abi3-manylinux2014_x86_64.whl (409 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.21.12 which is incompatible.
# Successfully installed protobuf-4.21.12

# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.0

# %%
import mysql.connector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-9cd6224ba968> in <cell line: 1>()
# ----> 1 import mysql.connector
#
# ModuleNotFoundError: No module named 'mysql'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install --upgrade --force-reinstall protobuf==3.20.3
# Out:
# Collecting protobuf==3.20.3
#   Using cached protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.21.12
#     Uninstalling protobuf-4.21.12:
#       Successfully uninstalled protobuf-4.21.12
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mysql-connector-python 8.1.0 requires protobuf<=4.21.12,>=4.21.1, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed protobuf-3.20.3

# %%
query = "CREATE TABLE if not exists aggregated_transaction(\
                            state VARCHAR(255),\
                            year INT,\
                            quarter VARCHAR(2),\
                            transaction_type VARCHAR(255),\
                            transaction_count INT,\
                            transaction_amount DOUBLE)"
cursor.execute(query)

# %%
query = "CREATE TABLE if not exists aggregated_user(\
                            state VARCHAR(255),\
                            year INT,\
                            quarter VARCHAR(2),\
                            user_brand VARCHAR(255),\
                            user_count INT,\
                            user_percentage DOUBLE)"
cursor.execute(query)

# %%
query = "CREATE TABLE if not exists map_transaction(\
                            state VARCHAR(255),\
                            year INT,\
                            quarter VARCHAR(2),\
                            district VARCHAR(255),\
                            transaction_count INT,\
                            transaction_amount DOUBLE)"
cursor.execute(query)

# %%
query = "CREATE TABLE if not exists map_user(\
                            state VARCHAR(255),\
                            year INT,\
                            quarter VARCHAR(2),\
                            district VARCHAR(255),\
                            registered_user INT,\
                            app_opens INT)"
cursor.execute(query)

# %%
query = "CREATE TABLE if not exists top_transaction_district(\
                            state VARCHAR(255),\
                            year INT,\
                            quarter VARCHAR(2),\
                            district VARCHAR(255),\
                            transaction_count INT,\
                            transaction_amount DOUBLE)"
cursor.execute(query)

# %%
query = "CREATE TABLE if not exists top_transaction_pincode(\
                            state VARCHAR(255),\
                            year INT,\
                            quarter VARCHAR(2),\
                            pincode VARCHAR(255),\
                            transaction_count INT,\
                            transaction_amount DOUBLE)"
cursor.execute(query)

# %%
query = "CREATE TABLE if not exists top_user_district(\
                            state VARCHAR(255),\
                            year INT,\
                            quarter VARCHAR(2),\
                            district VARCHAR(255),\
                            registered_user INT)"
cursor.execute(query)

# %%
query = "CREATE TABLE if not exists top_user_pincode(\
                            state VARCHAR(255),\
                            year INT,\
                            quarter VARCHAR(2),\
                            pincode VARCHAR(255),\
                            registered_user INT)"
cursor.execute(query)
